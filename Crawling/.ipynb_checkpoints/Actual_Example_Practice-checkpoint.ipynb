# %% [markdown]
# ### (1) 연습1. 네이버 쇼핑 BEST 100 실시간 검색어 가져오기

# %%
import requests
from bs4 import BeautifulSoup

headers = {'User-Agent':'Mozilla/5.0 (Windows NT 6.3; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/63.0.3239.132 Safari/537.36'}

res = requests.get('https://search.shopping.naver.com/best100v2/main.nhn', headers = headers)
soup = BeautifulSoup(res.content, 'html.parser')

ul = soup.find(id = 'popular_srch_lst')
a = ul.select('a._popular_srch_lst_li')

for index,item in enumerate(a):
    print (str(index + 1) +'위 : ' + item.get_text())
# Out:
# 1위 : KF94 마스크
# 2위 : 마스크 스트랩
# 3위 : 헤드셋
# 4위 : 면도기
# 5위 : 마스크
# 6위 : 비접촉 체온계
# 7위 : 닌텐도 스위치
# 8위 : KF80 마스크
# 9위 : 보석십자수
# 10위 : 에어팟 프로

# %% [markdown]
# ### (2) 네이버 주식 사이트 인기 검색 종목 가져오기

# %%
import requests
from bs4 import BeautifulSoup

headers = {'User-Agent':'Mozilla/5.0 (Windows NT 6.3; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/63.0.3239.132 Safari/537.36'}

res = requests.get('https://finance.naver.com/sise/lastsearch2.nhn', headers = headers)
soup = BeautifulSoup(res.content, 'html.parser')

div = soup.find('div', 'box_type_l')
a = div.select('table a')

for index,item in enumerate(a):
    print (str(index + 1) +'위 : ' + item.get_text())
# Out:
# 1위 : 진원생명과학
# 2위 : 삼성전자
# 3위 : 카카오
# 4위 : 삼성전자우
# 5위 : KT&G
# 6위 : NAVER
# 7위 : 두산중공업
# 8위 : SK텔레콤
# 9위 : 이크레더블
# 10위 : LG화학
# 11위 : 고려신용정보
# 12위 : 신풍제약
# 13위 : SK하이닉스
# 14위 : 맥쿼리인프라
# 15위 : 엑세스바이오
# 16위 : 알서포트
# 17위 : 씨젠
# 18위 : 현대차
# 19위 : LG생활건강
# 20위 : 신영증권우
# 21위 : 제넥신
# 22위 : 미래에셋대우2우B
# 23위 : 셀트리온
# 24위 : 롯데리츠
# 25위 : 삼성바이오로직스
# 26위 : KB금융
# 27위 : 바이넥스
# 28위 : 현대모비스
# 29위 : 제노포커스
# 30위 : 우양

# %% [markdown]
# ### (3) 환율

# %%
import requests
from bs4 import BeautifulSoup

headers = {'User-Agent':'Mozilla/5.0 (Windows NT 6.3; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/63.0.3239.132 Safari/537.36'}

res = requests.get('https://finance.naver.com/marketindex/exchangeList.nhn', headers = headers)
soup = BeautifulSoup(res.content, 'html.parser')

title = soup.select('td.tit')
sale = soup.select('td.sale')

for index, item in enumerate(sale):
    print(title[index].get_text().strip()+ ' : ' + item.get_text() )
    print()
# Out:
# 미국 USD : 1,183.00
#
# 유럽연합 EUR : 1,408.07
#
# 일본 JPY (100엔) : 1,122.87
#
# 중국 CNY : 172.36
#
# 홍콩 HKD : 152.64
#
# 대만 TWD : 40.30
#
# 영국 GBP : 1,573.92
#
# 오만 OMR : 3,072.73
#
# 캐나다 CAD : 905.61
#
# 스위스 CHF : 1,309.57
#
# 스웨덴 SEK : 137.08
#
# 호주 AUD : 866.43
#
# 뉴질랜드 NZD : 792.20
#
# 체코 CZK : 53.71
#
# 칠레 CLP : 1.51
#
# 터키 TRY : 161.46
#
# 몽골 MNT : 0.41
#
# 이스라엘 ILS : 351.31
#
# 덴마크 DKK : 189.16
#
# 노르웨이 NOK : 134.62
#
# 사우디아라비아 SAR : 315.42
#
# 쿠웨이트 KWD : 3,874.12
#
# 바레인 BHD : 3,140.68
#
# 아랍에미리트 AED : 322.07
#
# 요르단 JOD : 1,668.55
#
# 이집트 EGP : 74.54
#
# 태국 THB : 37.98
#
# 싱가포르 SGD : 869.73
#
# 말레이시아 MYR : 284.00
#
# 인도네시아 IDR 100 : 8.11
#
# 카타르 QAR : 324.91
#
# 카자흐스탄 KZT : 2.81
#
# 브루나이 BND : 869.73
#
# 인도 INR : 16.14
#
# 파키스탄 PKR : 7.07
#
# 방글라데시 BDT : 13.95
#
# 필리핀 PHP : 24.42
#
# 멕시코 MXN : 53.99
#
# 브라질 BRL : 212.39
#
# 베트남 VND 100 : 5.10
#
# 남아프리카 공화국 ZAR : 70.74
#
# 러시아 RUB : 15.92
#
# 헝가리 HUF : 3.96
#
# 폴란드 PLN : 320.49

# %% [markdown]
# ### (4) 닥터아파트 분양뉴스에서 금일자 뉴스 타이틀 가져오기

# %%
import requests
from bs4 import BeautifulSoup

res = requests.get('http://www.drapt.com/e_sale/index.htm?page_name=esale_news&menu_key=34')
soup = BeautifulSoup(res.content, 'html.parser')

p = soup.select('a.c0000000')

for item in p:
    print(item.get_text())
# Out:
#  3기신도시 밑그림 완성…내년부터 6만가구 사전청약
#  6만명 청약몰린 수색뉴타운…`DMC 3총사` 70점돼야 안심
#  규제묶이자…평택·인천 청약 차갑게 식는다
#  원베일리 분양가 5500만원? 4382만원?…정부 마음에 달렸다
#  지분형분양도 공공주도…결국 또 혈세투입?
#  내년 2월 수도권 민간택지 분양가상한제 주택 2~3년 거주의무
#  정부, 유휴부지 등 개발 속도내나…택지개발된 과천청사 내년 ..
#  뒤통수 맞은 50대 "정부믿고 착실히 청약가점 쌓았는데…"
#  "분양가 더 낮아지나" 민간택지 분양가상한제 29일 본격 부활
#  SH공사, 공공분양 건설원가 공개키로…업계 파장
#  "5억 로또는 우리 것"…세대간 전쟁터 된 청약
#  "정부 믿고 20년 청약저축했는데"…4050분노
#  30대 절규 이제야 들렸나…생애최초·신혼부부 특공 확대
#  `124대1` 고덕강일 공공분양, 매월 10만원씩 18년 부어야 당첨
#  "입주 코앞인데 잔금대출 40%로 묶어" 분양자들 날벼락

# %% [markdown]
# #### [ 페이지 이동을 고려한 크롤링 ]
# - 페이지 이동을 고려하여 크롤링을 진행할때는 해당 페이지의 URL 패턴을 파악해야한다.
# - 해당 사진은 닥터아파트 분양뉴스의 페이지별 URL 이다.
#     ![6](https://user-images.githubusercontent.com/53929665/91991102-7649fd00-ed6d-11ea-9f5c-18a2755d4eb5.JPG)
#
# - 위 사진에서 2페이지 ~ 4페이지 사이에서 유사한 패턴을 확인 할 수 있다.
# - 더불어, http://www.drapt.com/e_sale/index.htm?page_name=esale_news&menu_key=34&view_count=15&mode=&field=&s_que=&okey=wdate&start=0 이라고 검색했을시, 1페이지가 링크되는 것을 확인할 수 있다.
# - 따라서, URL의 끝자리가 15의 배수 순으로 나뉘어지는 패턴을 발견할 수 있다.

# %%
import requests
from bs4 import BeautifulSoup

for index in range(4):
    res = requests.get('http://www.drapt.com/e_sale/index.htm?page_name=esale_news&menu_key=34&view_count=15&mode=&field=&s_que=&okey=wdate&start=' + str(index*15))
    soup = BeautifulSoup(res.content, 'html.parser')

    a = soup.select('a.c0000000')
    
    print('page' + str(index+1))
    
    for item in a:
        print(item.get_text())
# Out:
# page1
#  3기신도시 밑그림 완성…내년부터 6만가구 사전청약
#  6만명 청약몰린 수색뉴타운…`DMC 3총사` 70점돼야 안심
#  규제묶이자…평택·인천 청약 차갑게 식는다
#  원베일리 분양가 5500만원? 4382만원?…정부 마음에 달렸다
#  지분형분양도 공공주도…결국 또 혈세투입?
#  내년 2월 수도권 민간택지 분양가상한제 주택 2~3년 거주의무
#  정부, 유휴부지 등 개발 속도내나…택지개발된 과천청사 내년 ..
#  뒤통수 맞은 50대 "정부믿고 착실히 청약가점 쌓았는데…"
#  "분양가 더 낮아지나" 민간택지 분양가상한제 29일 본격 부활
#  SH공사, 공공분양 건설원가 공개키로…업계 파장
#  "5억 로또는 우리 것"…세대간 전쟁터 된 청약
#  "정부 믿고 20년 청약저축했는데"…4050분노
#  30대 절규 이제야 들렸나…생애최초·신혼부부 특공 확대
#  `124대1` 고덕강일 공공분양, 매월 10만원씩 18년 부어야 당첨
#  "입주 코앞인데 잔금대출 40%로 묶어" 분양자들 날벼락
# page2
#  "분양전환하니 6억 로또"…미사 부영아파트
#  강남구 분양가 또 `4750만원`
#  잔금대출은 어찌하나…6.17대책에 청약 당첨되도 발동동
#  가점 모자라, 추첨 없어져…`청포족` 된 30대, 울분의 매수
#  둔촌주공 분양가 3천만원 넘길 듯
#  투기판 된 청약…서울아파트 99대1
#  "당첨되면 10억…이정도 불법쯤이야"…적발된 가짜임신진단서만..
#  HUG 분양가 규제…수억원 차익 `로또 청약`에 전국이 들썩
#  5월 초 분양했던 고양 덕은 자이아파트, 미계약물량 `우수수`
#  `규제 시작되기 전에 아파트 마련하자`…전국에 청약 광풍
#  서울 아닌 곳도 뜨거운 청약 열기…화성 동탄역헤리엇 150대 1
#  9억 넘는 분양가에 대출 막혀…`그림의 떡` 청약
#  수원에도 청약 부적격자 우수수…영통자이도 `줍줍`
#  흑석리버파크자이 청약가점 만점 등장…서울서 1년 반만에 처음
#  앞으로 수도권 모든 공공분양 최대 5년 거주 의무…못채우면 환..
# page3
#  수원 분양가도 최고가 경신
#  규제 강화·코로나에도 청약 열기…흑석동 GS자이 96대 1
#  결혼 7년 지나도 늦둥이 있으면 신혼희망타운 분양받는다
#  유자녀 부부 신혼희망타운 청약해도 신혼부부 디딤돌대출은 안..
#  위례서 마지막 민간분양…서울·경기 공공택지 막판 청약률은
#  높은 분양가에…"가점 10점대 1인가구도 당첨"
#  시세10억 하남 아파트가 5억에 나왔다
#  주택공급 확대·전매제한 강화 발표에도 청약시장 여전히…
#  "분양권전매 막차타자"…통장 5만개 몰렸다
#  "분양권 규제전에…" 송도 줍줍 몰려든 6만명
#  공공분양 사전청약 해볼까…남양주·하남·과천·인천 첫선
#  10년간 재당첨 금지…서울 청약규제 첫 적용
#  수도권 3기 신도시 조기 분양한다…내년 9천가구 사전청약
#  위례 2건 `줍줍`에…현금 16억 들고 4천명 달려왔다
#  인천등 비규제지역 청약열기…`강남급`가점
# page4
#  지역주택조합 아파트도 후분양 나온다
#  코로나 무색한 아파트 청약 열기…연초 분양 75%가 1순위 마감
#  서울·과천·분당 2년 살아야 청약1순위 자격
#  `로또청약` 후폭풍…과천 10명중 3명 부적격자
#  서울·과천보다 비싼 고양 분양가…고무줄 잣대 논란 재점화
#  고양 고무줄 분양가…1900만원 vs 2630만원
#  `미분양 무덤`이었던 인천 검단도 청약 열풍…최고경쟁률 경신
#  한곳 오래살수록 아파트 청약 유리해지나…거주기간 가점 검토
#  수도권 비규제 청약 인기라지만…분양가 시세보다 더 비싸
#  이달 중순부터 수도권 청약1순위 거주기간 1년→2년 강화
#  로또분양 현금부자 독식…"채권입찰제 필요"
#  서울 10곳 6천가구 더…상한제 피해 분양
#  앞으로 1년간은 급매 잡을 기회
#  "무주택자인데…투기꾼 취급" 청약 1순위 원안 확정에 실수요자..
#  16일부터 수도권·광역시 예비당첨자 비율 40%→300% 확대

# %% [markdown]
# #### [ 다음 소스와 같이 클래스가 여러개인 경우 ]
# - 해당 소스에서는 class가 ffth, fs11, c807f7f 총 3개의 클래스로 이루어진 것을 확인 할 수 있다.
# ```python
# <span class="ffth fs11 c807f7f">2020-09-01</span>
# ```
#
# - 위 소스는 아래와 같이 크롤링한다.

# %%
import requests
from bs4 import BeautifulSoup

res = requests.get('http://www.drapt.com/e_sale/index.htm?page_name=esale_news&menu_key=34')
soup = BeautifulSoup(res.content, 'html.parser')

title_a = soup.select('a.c0000000')    
date_span = soup.select('span.ffth.fs11.c807f7f')

for num, title in enumerate(title_a):
    print(date_span[num].get_text(),'=>', title.get_text())
# Out:
# 2020-09-01 =>  3기신도시 밑그림 완성…내년부터 6만가구 사전청약
# 2020-08-27 =>  6만명 청약몰린 수색뉴타운…`DMC 3총사` 70점돼야 안심
# 2020-08-26 =>  규제묶이자…평택·인천 청약 차갑게 식는다
# 2020-08-19 =>  원베일리 분양가 5500만원? 4382만원?…정부 마음에 달렸다
# 2020-08-13 =>  지분형분양도 공공주도…결국 또 혈세투입?
# 2020-08-12 =>  내년 2월 수도권 민간택지 분양가상한제 주택 2~3년 거주의무
# 2020-08-11 =>  정부, 유휴부지 등 개발 속도내나…택지개발된 과천청사 내년 ..
# 2020-08-07 =>  뒤통수 맞은 50대 "정부믿고 착실히 청약가점 쌓았는데…"
# 2020-07-30 =>  "분양가 더 낮아지나" 민간택지 분양가상한제 29일 본격 부활
# 2020-07-29 =>  SH공사, 공공분양 건설원가 공개키로…업계 파장
# 2020-07-27 =>  "5억 로또는 우리 것"…세대간 전쟁터 된 청약
# 2020-07-13 =>  "정부 믿고 20년 청약저축했는데"…4050분노
# 2020-07-07 =>  30대 절규 이제야 들렸나…생애최초·신혼부부 특공 확대
# 2020-06-30 =>  `124대1` 고덕강일 공공분양, 매월 10만원씩 18년 부어야 당첨
# 2020-06-26 =>  "입주 코앞인데 잔금대출 40%로 묶어" 분양자들 날벼락

# %% [markdown]
# #### [ 원하는 날짜의 뉴스 타이틀 가져오기 ]

# %% [markdown]
# - ★★★★★<b>날짜 모듈 연산</b>
#     - 필요 라이브러리 : <b>`datetime`</b>
#     - 형태 : <b>`timedelta(기준 = 숫자)`</b>
#     - 기준 가능 인수 : `seconds`, `hours`, `days`, `weeks`
#     - 응용 :
#     ```python
#     datetime.date.today() + timedelta(days = -5) # 5일전
#     ```

# %%
import datetime
import requests
from bs4 import BeautifulSoup

date_today = datetime.date.today()
date_last = datetime.timedelta(days=2)

res = requests.get('http://www.drapt.com/e_sale/index.htm?page_name=esale_news&menu_key=34')
soup = BeautifulSoup(res.content, 'html.parser')

title_a = soup.select('a.c0000000')    
date_span = soup.select('span.ffth.fs11.c807f7f')

for num, title in enumerate(title_a):
    if date_span[num].get_text() == str(date_today - date_last):
        print(date_span[num].get_text(),'=>', title.get_text())
# Out:
# 2020-09-01 =>  3기신도시 밑그림 완성…내년부터 6만가구 사전청약

# %% [markdown]
# #### [ 특정 태그의 속성 가져와서 링크 만들기 ]

# %% [markdown]
# - 보통 HTML에서 `<a>`태그는 다른 사이트로 이동함을 알리기위해서,
# `href`속성은 이동하려는 사이트의 URL을 알려주기 위해서 사용된다.
#
#
# - 뉴스본문으로 접속하기 위한 뉴스타이틀 제목의 하이퍼링크 URL은
# 다음의 예시에서는 `href`의 속성값과 <U>http://www.drapt.com/e_sale/</U>이 합쳐져 만들어졌다.
# 따라서, 다른 뉴스타이틀의 `href` 속성값을 크롤링하여 해당 뉴스 본문으로 접속하기 위한 URL들을 만들어 낼 수 있다.
#
# ![7](https://user-images.githubusercontent.com/53929665/92103229-9e436a00-ee1a-11ea-8c56-9e4ea5eed1af.JPG)
#
# - ★★★★★ 속성값을 불러오는 방법은 딕셔너리에서 value를 출력하는 과정과 동일하다.
#     - `객체['속성명']`

# %%
import requests
from bs4 import BeautifulSoup

res = requests.get('http://www.drapt.com/e_sale/index.htm?page_name=esale_news&menu_key=34')
soup = BeautifulSoup(res.content, 'html.parser')

title_a = soup.select('a.c0000000')    

for title in title_a:
    print(title.get_text(), ':', 'http://www.drapt.com/e_sale/' + title['href']) # hot point!
# Out:
#  3기신도시 밑그림 완성…내년부터 6만가구 사전청약 : http://www.drapt.com/e_sale/index.htm?page_name=esale_news_view&menu_key=34&okey=wdate&uid=358317&start=0&mode=&s_que=&field=
#  6만명 청약몰린 수색뉴타운…`DMC 3총사` 70점돼야 안심 : http://www.drapt.com/e_sale/index.htm?page_name=esale_news_view&menu_key=34&okey=wdate&uid=358302&start=0&mode=&s_que=&field=
#  규제묶이자…평택·인천 청약 차갑게 식는다 : http://www.drapt.com/e_sale/index.htm?page_name=esale_news_view&menu_key=34&okey=wdate&uid=358296&start=0&mode=&s_que=&field=
#  원베일리 분양가 5500만원? 4382만원?…정부 마음에 달렸다 : http://www.drapt.com/e_sale/index.htm?page_name=esale_news_view&menu_key=34&okey=wdate&uid=358266&start=0&mode=&s_que=&field=
#  지분형분양도 공공주도…결국 또 혈세투입? : http://www.drapt.com/e_sale/index.htm?page_name=esale_news_view&menu_key=34&okey=wdate&uid=358254&start=0&mode=&s_que=&field=
#  내년 2월 수도권 민간택지 분양가상한제 주택 2~3년 거주의무 : http://www.drapt.com/e_sale/index.htm?page_name=esale_news_view&menu_key=34&okey=wdate&uid=358248&start=0&mode=&s_que=&field=
#  정부, 유휴부지 등 개발 속도내나…택지개발된 과천청사 내년 .. : http://www.drapt.com/e_sale/index.htm?page_name=esale_news_view&menu_key=34&okey=wdate&uid=358236&start=0&mode=&s_que=&field=
#  뒤통수 맞은 50대 "정부믿고 착실히 청약가점 쌓았는데…" : http://www.drapt.com/e_sale/index.htm?page_name=esale_news_view&menu_key=34&okey=wdate&uid=358223&start=0&mode=&s_que=&field=
#  "분양가 더 낮아지나" 민간택지 분양가상한제 29일 본격 부활 : http://www.drapt.com/e_sale/index.htm?page_name=esale_news_view&menu_key=34&okey=wdate&uid=358187&start=0&mode=&s_que=&field=
#  SH공사, 공공분양 건설원가 공개키로…업계 파장 : http://www.drapt.com/e_sale/index.htm?page_name=esale_news_view&menu_key=34&okey=wdate&uid=358183&start=0&mode=&s_que=&field=
#  "5억 로또는 우리 것"…세대간 전쟁터 된 청약 : http://www.drapt.com/e_sale/index.htm?page_name=esale_news_view&menu_key=34&okey=wdate&uid=358164&start=0&mode=&s_que=&field=
#  "정부 믿고 20년 청약저축했는데"…4050분노 : http://www.drapt.com/e_sale/index.htm?page_name=esale_news_view&menu_key=34&okey=wdate&uid=358100&start=0&mode=&s_que=&field=
#  30대 절규 이제야 들렸나…생애최초·신혼부부 특공 확대 : http://www.drapt.com/e_sale/index.htm?page_name=esale_news_view&menu_key=34&okey=wdate&uid=358078&start=0&mode=&s_que=&field=
#  `124대1` 고덕강일 공공분양, 매월 10만원씩 18년 부어야 당첨 : http://www.drapt.com/e_sale/index.htm?page_name=esale_news_view&menu_key=34&okey=wdate&uid=358052&start=0&mode=&s_que=&field=
#  "입주 코앞인데 잔금대출 40%로 묶어" 분양자들 날벼락 : http://www.drapt.com/e_sale/index.htm?page_name=esale_news_view&menu_key=34&okey=wdate&uid=358036&start=0&mode=&s_que=&field=

# %% [markdown]
# ### (5) 다음 뉴스 경제사이트에서 링크 모두
#
# - ★★★★★ <U>특정 태그</U>에 <U>특정한 속성</U>이 있는 내용들을 모두 가져오는 방법
#     ```python
#     데이터 저장 객체 = 파싱객체.select('태그[속성]')
#     ```

# %%
import requests
from bs4 import BeautifulSoup

res = requests.get('https://news.daum.net/economic')
soup = BeautifulSoup(res.content, 'html.parser')

links = soup.select('a[class]') # hot point!

for link in links:
    print(link['href'])
# Out:
# https://entertain.daum.net
# https://sports.daum.net
# /
# /society
# /politics
# /economic
# /foreign
# /culture
# /digital
# /ranking/popular
# /series/
# /photo
# /tv/
# /1boon
# https://gallery.v.daum.net/p/home
# http://search.daum.net/search?w=tot&DA=23W&rtmaxcoll=Z8T&q=서울특별시날씨
# http://search.daum.net/search?w=tot&DA=23W&rtmaxcoll=Z8T&q=수원시 권선구날씨
# http://search.daum.net/search?w=tot&DA=23W&rtmaxcoll=Z8T&q=인천광역시날씨
# http://search.daum.net/search?w=tot&DA=23W&rtmaxcoll=Z8T&q=대구광역시날씨
# http://search.daum.net/search?w=tot&DA=23W&rtmaxcoll=Z8T&q=대전광역시날씨
# http://search.daum.net/search?w=tot&DA=23W&rtmaxcoll=Z8T&q=광주광역시날씨
# http://search.daum.net/search?w=tot&DA=23W&rtmaxcoll=Z8T&q=부산광역시날씨
# http://search.daum.net/search?w=tot&DA=23W&rtmaxcoll=Z8T&q=울산광역시날씨
# http://search.daum.net/search?w=tot&DA=23W&rtmaxcoll=Z8T&q=울릉군날씨
# http://search.daum.net/search?w=tot&DA=23W&rtmaxcoll=Z8T&q=춘천시날씨
# http://search.daum.net/search?w=tot&DA=23W&rtmaxcoll=Z8T&q=강릉시날씨
# http://search.daum.net/search?w=tot&DA=23W&rtmaxcoll=Z8T&q=백령면날씨
# http://search.daum.net/search?w=tot&DA=23W&rtmaxcoll=Z8T&q=청주시 상당구날씨
# http://search.daum.net/search?w=tot&DA=23W&rtmaxcoll=Z8T&q=전주시 완산구날씨
# http://search.daum.net/search?w=tot&DA=23W&rtmaxcoll=Z8T&q=목포시날씨
# http://search.daum.net/search?w=tot&DA=23W&rtmaxcoll=Z8T&q=여수시날씨
# http://search.daum.net/search?w=tot&DA=23W&rtmaxcoll=Z8T&q=제주특별자치도날씨
# http://search.daum.net/search?w=tot&DA=23W&rtmaxcoll=Z8T&q=안동시날씨
# http://search.daum.net/search?w=tot&DA=23W&rtmaxcoll=Z8T&q=창원시 의창구날씨
# https://news.v.daum.net/v/20200903192736119
# https://news.v.daum.net/v/20200903192736119
# https://news.v.daum.net/v/20200903171428176
# https://news.v.daum.net/v/20200903145007873
# https://news.v.daum.net/v/20200903191603909
# https://news.v.daum.net/v/20200903191603909
# https://news.v.daum.net/v/20200903174122439
# https://news.v.daum.net/v/20200903190837770
# https://news.v.daum.net/v/20200903190837770
# https://news.v.daum.net/v/20200903181606629
# https://news.v.daum.net/v/20200903185450387
# https://news.v.daum.net/v/20200903185450387
# https://news.v.daum.net/v/20200903161259226
# https://news.v.daum.net/v/20200903182841921
# https://news.v.daum.net/v/20200903182841921
# https://news.v.daum.net/v/20200903172047453
# https://news.v.daum.net/v/20200903181249469
# https://news.v.daum.net/v/20200903141613542
# https://news.v.daum.net/v/20200903192251021
# https://news.v.daum.net/v/20200903190555714
# https://news.v.daum.net/v/20200903160727046
# https://1boon.kakao.com/newsbot/briefing
# /issue/1436001
# https://v.daum.net/v/20200903192606087
# https://v.daum.net/v/20200903184034137
# https://v.daum.net/v/20200903181251470
# /issue/5095578
# https://v.daum.net/v/20200903185619416
# https://v.daum.net/v/20200903160721041
# https://v.daum.net/v/20200903141938692
# /issue/1805781
# https://v.daum.net/v/20200903180600284
# https://v.daum.net/v/20200903143544326
# https://v.daum.net/v/20200831063013233
# /issue/economic
# https://v.daum.net/v/20200903175812993
# /series/111391
# https://v.daum.net/v/20200903175812993
# https://v.daum.net/v/20200903164707842
# /series/1652928
# https://v.daum.net/v/20200903164707842
# https://v.daum.net/v/20200903160100764
# /series/1380677
# https://v.daum.net/v/20200903160100764
# https://v.daum.net/v/20200903142102746
# /series/366438
# https://v.daum.net/v/20200903142102746
# https://v.daum.net/v/20200903140837143
# /series/1398145
# https://v.daum.net/v/20200903140837143
# https://v.daum.net/v/20200903173804346
# https://v.daum.net/v/20200903173804346
# https://v.daum.net/v/20200903105509513
# https://v.daum.net/v/20200903105509513
# https://v.daum.net/v/20200903154353192
# https://v.daum.net/v/20200903154353192
# https://v.daum.net/v/20200903181252472
# https://v.daum.net/v/20200903181252472
# /ranking/age
# https://v.daum.net/v/20200903164038523
# https://v.daum.net/v/20200903164038523
# https://v.daum.net/v/20200903184034137
# https://v.daum.net/v/20200903184034137
# https://v.daum.net/v/20200903180050106
# https://v.daum.net/v/20200903180050106
# https://v.daum.net/v/20200903043047381
# https://v.daum.net/v/20200903043047381
# /ranking/age
# http://v.media.daum.net/v/20200903043047381
# http://v.media.daum.net/v/20200903180050106
# http://v.media.daum.net/v/20200903105509513
# http://v.media.daum.net/v/20200903181252472
# /ranking/bestreply
# /breakingnews/economic
# #none
# https://v.daum.net/v/20200903164535769
# https://v.daum.net/v/20200903182124764
# https://v.daum.net/v/20200903184502202
# https://v.daum.net/v/20200903043047381
# https://v.daum.net/v/20200903171127056
# https://v.daum.net/v/20200903184523210
# https://v.daum.net/v/20200903182212779
# https://v.daum.net/v/20200903184202158
# https://v.daum.net/v/20200903180050106
# https://v.daum.net/v/20200903175202778
# https://v.daum.net/v/20200903174350501
# https://v.daum.net/v/20200903182221783
# https://v.daum.net/v/20200903172552676
# https://v.daum.net/v/20200903171836398
# https://v.daum.net/v/20200903181300476
# https://v.daum.net/v/20200903160653020
# https://v.daum.net/v/20200903190016532
# https://v.daum.net/v/20200903180548276
# https://v.daum.net/v/20200903184240175
# https://v.daum.net/v/20200903164809879
# https://v.daum.net/v/20200903180158148
# https://v.daum.net/v/20200903180952399
# https://v.daum.net/v/20200903172203532
# https://v.daum.net/v/20200903165218105
# https://v.daum.net/v/20200903182219782
# https://v.daum.net/v/20200903180022079
# https://v.daum.net/v/20200903171736329
# https://v.daum.net/v/20200903145620105
# https://v.daum.net/v/20200903184034137
# https://v.daum.net/v/20200903182231785
# #none
# https://v.daum.net/v/20200903151842118?s=eRIGHT_MANY_TOT=R
# https://v.daum.net/v/20200903150512522?s=eRIGHT_MANY_TOT=R
# https://v.daum.net/v/20200903152211276?s=eRIGHT_MANY_TOT=R
# https://v.daum.net/v/20200903145235973?s=eRIGHT_MANY_TOT=R
# https://v.daum.net/v/20200903170800876?s=eRIGHT_MANY_TOT=R
# https://v.daum.net/v/20200903133004878?s=eRIGHT_MANY_TOT=R
# https://v.daum.net/v/20200903155136437?s=eRIGHT_MANY_TOT=R
# https://v.daum.net/v/20200903081704766?s=eRIGHT_MANY_TOT=R
# https://v.daum.net/v/20200903133320959?s=eRIGHT_MANY_TOT=R
# https://v.daum.net/v/20200903144807808?s=eRIGHT_MANY_TOT=R
# https://v.daum.net/v/20200903180007055?s=eRIGHT_MANY_TOT=R
# https://v.daum.net/v/20200903093454928?s=eRIGHT_MANY_TOT=R
# https://v.daum.net/v/20200903134545289?s=eRIGHT_MANY_TOT=R
# https://v.daum.net/v/20200903153806981?s=eRIGHT_MANY_TOT=R
# https://v.daum.net/v/20200903173122982?s=eRIGHT_MANY_TOT=R
# https://v.daum.net/v/20200903131200449?s=eRIGHT_MANY_TOT=R
# https://v.daum.net/v/20200903114716327?s=eRIGHT_MANY_TOT=R
# https://v.daum.net/v/20200903152604449?s=eRIGHT_MANY_TOT=R
# https://v.daum.net/v/20200903163615306?s=eRIGHT_MANY_TOT=R
# https://v.daum.net/v/20200903160324874?s=eRIGHT_MANY_TOT=R
# https://v.daum.net/v/20200903060937809?s=eRIGHT_MANY_TOT=R
# https://v.daum.net/v/20200903183153994?s=eRIGHT_MANY_TOT=R
# https://v.daum.net/v/20200903162607754?s=eRIGHT_MANY_TOT=R
# https://v.daum.net/v/20200903111234674?s=eRIGHT_MANY_TOT=R
# https://v.daum.net/v/20200903174721634?s=eRIGHT_MANY_TOT=R
# https://v.daum.net/v/20200903083148151?s=eRIGHT_MANY_TOT=R
# https://v.daum.net/v/20200903132704812?s=eRIGHT_MANY_TOT=R
# https://v.daum.net/v/20200903143951510?s=eRIGHT_MANY_TOT=R
# https://v.daum.net/v/20200903190139611?s=eRIGHT_MANY_TOT=R
# https://v.daum.net/v/20200903181830704?s=eRIGHT_MANY_TOT=R
# #none
# https://v.daum.net/v/20200903170146538
# https://v.daum.net/v/20200903170602773
# https://v.daum.net/v/20200903144150571
# https://v.daum.net/v/20200903111217658
# https://v.daum.net/v/20200903131318480
# https://v.daum.net/v/20200903113125671
# https://v.daum.net/v/20200903170002438
# https://v.daum.net/v/20200903151648039
# https://v.daum.net/v/20200903160607986
# https://v.daum.net/v/20200903170603780
# https://v.daum.net/v/20200903105901693
# https://v.daum.net/v/20200903173045930
# https://v.daum.net/v/20200903154651276
# https://v.daum.net/v/20200903174406506
# https://v.daum.net/v/20200903105414475
# https://v.daum.net/v/20200903102915000
# https://v.daum.net/v/20200903173254054
# https://v.daum.net/v/20200903104150770
# https://v.daum.net/v/20200903145303982
# https://v.daum.net/v/20200903120903177
# https://v.daum.net/v/20200903170438689
# https://v.daum.net/v/20200903110550215
# https://v.daum.net/v/20200903145401022
# https://v.daum.net/v/20200903184006125
# https://v.daum.net/v/20200903095133828
# https://v.daum.net/v/20200903163806396
# https://v.daum.net/v/20200903110203918
# https://v.daum.net/v/20200903143824448
# https://v.daum.net/v/20200903052201172
# https://v.daum.net/v/20200903120150946
# /ranking/
# /
# /society
# /politics
# /economic
# /foreign
# /culture
# /digital
# /photo
# https://media.daum.net/tv
# /issue
# /cp
# /newsbox
# /breakingnews
# /ranking/popular
# /series
# /1boon
# /info/intro
# /notice
# /info/bbsrule
# http://policy.daum.net/info/info
# https://with.kakao.com/media
# https://business.kakao.com
# https://cs.daum.net/redbell/top.html
# http://cs.daum.net/faq/63.html
# /info/newscenter24
# /info/edit
# /info/correct
# http://www.kakaocorp.com/
